# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ============================================
# 🧩 STEP 1: SETUP ENVIRONMENT
# ============================================
# !nvidia-smi
# !pip install ninja gdown --quiet
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121 --quiet
# Out:
# Thu May  7 06:11:48 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             44W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
# !rm -rf /content/stylegan3

# %%
# ============================================
# 📦 STEP 3: CLONE STYLEGAN3 REPOSITORY
# ============================================
# %cd /content
# !git clone https://github.com/NVlabs/stylegan3.git
# %cd stylegan3
# Out:
# /content
# Cloning into 'stylegan3'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (166/166), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 212 (delta 101), reused 96 (delta 96), pack-reused 46 (from 1)
# Receiving objects: 100% (212/212), 4.16 MiB | 36.11 MiB/s, done.
# Resolving deltas: 100% (107/107), done.
# /content/stylegan3

# %%
# %cd /content
# !rm -rf stylegan3
# !git clone https://github.com/NVlabs/stylegan3.git
# %cd stylegan3
# !pip install -r requirements.txt
# Out:
# /content
# Cloning into 'stylegan3'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (166/166), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 212 (delta 101), reused 96 (delta 96), pack-reused 46 (from 1)
# Receiving objects: 100% (212/212), 4.16 MiB | 17.39 MiB/s, done.
# Resolving deltas: 100% (107/107), done.
# /content/stylegan3
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !pip install click requests tqdm pyspng ninja imageio-ffmpeg
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.9/193.9 kB 19.1 MB/s eta 0:00:00
# ...

# %%
# !sudo apt-get update -y
# !sudo apt-get install -y python3.9 python3.9-dev python3.9-distutils
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [91.2 kB]
# Get:12 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# ...

# %%
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.9 1

# %%
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3 get-pip.py
# Out:
# --2026-05-07 06:12:24--  https://bootstrap.pypa.io/get-pip.py
# Resolving bootstrap.pypa.io (bootstrap.pypa.io)... 151.101.0.175, 151.101.64.175, 151.101.128.175, ...
# Connecting to bootstrap.pypa.io (bootstrap.pypa.io)|151.101.0.175|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2226394 (2.1M) [text/x-python]
# Saving to: ‘get-pip.py’
#
# get-pip.py          100%[===================>]   2.12M  --.-KB/s    in 0.02s
#
# 2026-05-07 06:12:24 (92.0 MB/s) - ‘get-pip.py’ saved [2226394/2226394]
#
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.1 MB/s  0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %%
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu121
# !pip install click tqdm ninja requests pillow psutil scipy
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...

# %%
# !git clone https://github.com/NVlabs/stylegan3.git
# %cd stylegan3
# !pip install -r requirements.txt
# Out:
# Cloning into 'stylegan3'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 212 (delta 99), reused 90 (delta 90), pack-reused 49 (from 1)
# Receiving objects: 100% (212/212), 4.16 MiB | 25.06 MiB/s, done.
# Resolving deltas: 100% (108/108), done.
# /content/stylegan3/stylegan3
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# ============================================
# 🔧 STEP 5: VERIFY SETUP
# ============================================
# !ls /content/stylegan3/training
# !python -c "import torch; print('✅ Torch version:', torch.__version__)"
# Out:
# augment.py  __init__.py  networks_stylegan2.py	training_loop.py
# dataset.py  loss.py	 networks_stylegan3.py
# ✅ Torch version: 2.10.0+cu128

# %%
# Convert the image folder to StyleGAN3 dataset format
# !python /content/stylegan3/dataset_tool.py \
  --source=/content/drive/MyDrive/POTATODATASET/PLDDATASET/Healthy \
  --dest=/content/drive/MyDrive/POTATODATASET/PLDDATASET/Healthy.zip \
  --resolution=256x256
# Out:
#   0% 0/1020 [00:00<?, ?it/s]/content/stylegan3/dataset_tool.py:441: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   img = PIL.Image.fromarray(img, { 1: 'L', 3: 'RGB' }[channels])
# 100% 1020/1020 [00:24<00:00, 41.47it/s]

# %%
# !cp /content/drive/MyDrive/GALLMILDGEDAMAGE.zip /content/

# %%
# !sudo apt-get update -y
# !sudo apt-get install -y python3.9 python3.9-dev python3.9-distutils
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [90.8 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,608 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,995 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,913 kB]
# ...

# %%
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.9 1

# %%
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3 get-pip.py
# Out:
# --2026-05-06 07:48:44--  https://bootstrap.pypa.io/get-pip.py
# Resolving bootstrap.pypa.io (bootstrap.pypa.io)... 151.101.0.175, 151.101.64.175, 151.101.128.175, ...
# Connecting to bootstrap.pypa.io (bootstrap.pypa.io)|151.101.0.175|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2226394 (2.1M) [text/x-python]
# Saving to: ‘get-pip.py.1’
#
# get-pip.py.1        100%[===================>]   2.12M  --.-KB/s    in 0.07s
#
# 2026-05-06 07:48:45 (29.2 MB/s) - ‘get-pip.py.1’ saved [2226394/2226394]
#
# ...
#   Using cached pip-26.1.1-py3-none-any.whl.metadata (4.6 kB)
# Using cached pip-26.1.1-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 26.1.1
#     Uninstalling pip-26.1.1:
#       Successfully uninstalled pip-26.1.1
# ...

# %%
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...

# %%
# !pip install pillow scipy tqdm ninja psutil requests imageio imageio-ffmpeg click pyspng

# %%
# !git clone https://github.com/NVlabs/stylegan3.git
# %cd stylegan3
# Out:
# Cloning into 'stylegan3'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 212 (delta 99), reused 90 (delta 90), pack-reused 49 (from 1)
# Receiving objects: 100% (212/212), 4.16 MiB | 36.42 MiB/s, done.
# Resolving deltas: 100% (108/108), done.
# /content/stylegan3/stylegan3

# %%
# !python3 --version
# Out:
# Python 3.12.13

# %%
# !sudo apt-get update -y
# !sudo apt-get install -y python3.9 python3.9-dev python3.9-distutils
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:3 https://cli.github.com/packages stable InRelease
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:11 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# !python3.9 -m venv --without-pip /content/py39

# %%
# !wget https://bootstrap.pypa.io/get-pip.py -O /content/get-pip.py
# !/content/py39/bin/python3.9 /content/get-pip.py
# Out:
# --2026-05-07 06:23:03--  https://bootstrap.pypa.io/get-pip.py
# Resolving bootstrap.pypa.io (bootstrap.pypa.io)... 151.101.0.175, 151.101.64.175, 151.101.128.175, ...
# Connecting to bootstrap.pypa.io (bootstrap.pypa.io)|151.101.0.175|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2226394 (2.1M) [text/x-python]
# Saving to: ‘/content/get-pip.py’
#
# /content/get-pip.py 100%[===================>]   2.12M  --.-KB/s    in 0.02s
#
# 2026-05-07 06:23:03 (86.0 MB/s) - ‘/content/get-pip.py’ saved [2226394/2226394]
#
# ERROR: This script does not work on Python 3.9. The minimum supported Python version is 3.10. Please use https://bootstrap.pypa.io/pip/3.9/get-pip.py instead.

# %%
# !pip install pillow scipy tqdm ninja psutil requests imageio imageio-ffmpeg click pyspng

# %%
# !curl -sS https://bootstrap.pypa.io/pip/3.9/get-pip.py | python3.9
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 27.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 30.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [wheel]
# ...

# %%
# !python3.9 -m pip install pillow scipy tqdm ninja psutil requests imageio imageio-ffmpeg click pyspng
# Out:
# ...
#   Using cached ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 18.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 78.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 162.2 MB/s  0:00:00
# ...
# Using cached ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 189.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [imageio]
# ...

# %%
# !python3 --version
# Out:
# Python 3.12.13

# %%
# !python3.9 -m pip install torch==1.13.1 torchvision==0.14.1
# !python3.9 -m pip install pillow scipy tqdm ninja psutil requests imageio imageio-ffmpeg click pyspng
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 MB 26.3 MB/s  0:00:16
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 123.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 47.7 MB/s  0:00:05
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 79.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 54.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 32.5 MB/s  0:00:12
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 148.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 154.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/14 [torchvision]
# ...
#   Using cached ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 82.1 MB/s  0:00:00
# ...
# Using cached ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
# ...

# %%
# !python3.9 -c "import click; print('Click OK')"
# Out:
# Click OK

# %%
# !python3.9 -m pip install numpy==1.23.5
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 57.8 MB/s  0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ...

# %%
# !python3.9 -c "import numpy as np; print(np.__version__)"
# Out:
# 1.23.5

# %%
# !python3.9 /content/stylegan3/train.py \
  --outdir=/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB \
  --data=/content/drive/MyDrive/POTATODATASET/PLDDATASET/LateBlight.zip \
  --gpus=1 \
  --batch=8 \
  --cfg=stylegan3-r \
  --gamma=8.2 \
  --snap=10 \
  --kimg=1000 \
  --mirror=0 \
  --metrics=none
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 65536,
#     "channel_max": 1024,
#     "magnitude_ema_beta": 0.9997227795604651,
#     "conv_kernel": 1,
#     "use_radial_filters": true
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
# ...

# %%
# !python3.9 /content/stylegan3/train.py \
  --outdir=/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/EB \
  --data=/content/drive/MyDrive/POTATODATASET/PLDDATASET/EarlyBlight.zip \
  --gpus=1 \
  --batch=8 \
  --cfg=stylegan3-r \
  --gamma=8.2 \
  --snap=10 \
  --kimg=1000 \
  --mirror=0 \
  --metrics=none
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 65536,
#     "channel_max": 1024,
#     "magnitude_ema_beta": 0.9997227795604651,
#     "conv_kernel": 1,
#     "use_radial_filters": true
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
# ...

# %%
# !python3.9 /content/stylegan3/train.py \
  --outdir=/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/Healthy \
  --data=/content/drive/MyDrive/POTATODATASET/PLDDATASET/Healthy.zip \
  --gpus=1 \
  --batch=8 \
  --cfg=stylegan3-r \
  --gamma=8.2 \
  --snap=10 \
  --kimg=1000 \
  --mirror=0 \
  --metrics=none
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 65536,
#     "channel_max": 1024,
#     "magnitude_ema_beta": 0.9997227795604651,
#     "conv_kernel": 1,
#     "use_radial_filters": true
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
# ...

# %%
# !python3.9 /content/stylegan3/train.py \
  --outdir=/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB \
  --data=/content/drive/MyDrive/POTATODATASET/PLDDATASET/LateBlight.zip \
  --gpus=1 \
  --batch=8 \
  --cfg=stylegan3-r \
  --gamma=8.2 \
  --snap=10 \
  --kimg=1000 \
  --mirror=0 \
  --metrics=none \
  --resume=/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/00000-stylegan3-r-LateBlight-gpus1-batch8-gamma8.2/network-snapshot-000080.pkl
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 65536,
#     "channel_max": 1024,
#     "magnitude_ema_beta": 0.9997227795604651,
#     "conv_kernel": 1,
#     "use_radial_filters": true
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
# ...

# %%
# !python /content/stylegan3/gen_images.py \
  --outdir=/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LBGenerated \
  --seeds=0-1999 \
  --trunc=0.8 \
  --network=/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/00001-stylegan3-r-LateBlight-gpus1-batch8-gamma8.2/network-snapshot-000160.pkl
# Out:
# Loading networks from "/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/00001-stylegan3-r-LateBlight-gpus1-batch8-gamma8.2/network-snapshot-000160.pkl"...
# Generating image for seed 0 (0/2000) ...
# Setting up PyTorch plugin "bias_act_plugin"... Failed!
# Traceback (most recent call last):
#   File "/content/stylegan3/gen_images.py", line 143, in <module>
#     generate_images() # pylint: disable=no-value-for-parameter
#     ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 1514, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 1435, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 1298, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# %cd /content/stylegan3

# Clean old compiled plugins
# !rm -rf ~/.cache/torch_extensions
# !rm -rf /root/.cache/torch_extensions

# Rebuild StyleGAN3 ops
# !python setup.py build_ext --inplace
# Out:
# /content/stylegan3
# python3: can't open file '/content/stylegan3/setup.py': [Errno 2] No such file or directory

# %%
# !rm /content/stylegan3
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# rm: cannot remove '/content/stylegan3': No such file or directory

# %%
# %cd /content
# !git clone https://github.com/NVlabs/stylegan3.git
# Out:
# /content
# fatal: destination path 'stylegan3' already exists and is not an empty directory.

# %%
# !python3.9 -m pip install torch==1.13.1 torchvision==0.14.1
# !python3.9 -m pip install ninja click pillow scipy tqdm psutil requests imageio imageio-ffmpeg pyspng

# %%
# %cd /content/stylegan3

# !python3.9 -c "import torch.utils.cpp_extension"

# !python3.9 gen_images.py \
  --network=/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/00001-stylegan3-r-LateBlight-gpus1-batch8-gamma8.2/network-snapshot-000160.pkl \
  --outdir=/content/testgen \
  --seeds=0-1 \
  --trunc=0.7
# Out:
# /content/stylegan3
# Loading networks from "/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/00001-stylegan3-r-LateBlight-gpus1-batch8-gamma8.2/network-snapshot-000160.pkl"...
# Generating image for seed 0 (0/2) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
# /content/stylegan3/gen_images.py:137: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(img[0].cpu().numpy(), 'RGB').save(f'{outdir}/seed{seed:04d}.png')
# Generating image for seed 1 (1/2) ...

# %%
# !python3.9 /content/stylegan3/gen_images.py \
  --network=/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/00001-stylegan3-r-LateBlight-gpus1-batch8-gamma8.2/network-snapshot-000160.pkl \
  --outdir=/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/LBGenerated \
  --seeds=0-499 \
  --trunc=0.7
# Out:
# Loading networks from "/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/00001-stylegan3-r-LateBlight-gpus1-batch8-gamma8.2/network-snapshot-000160.pkl"...
# Generating image for seed 0 (0/500) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
# /content/stylegan3/gen_images.py:137: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(img[0].cpu().numpy(), 'RGB').save(f'{outdir}/seed{seed:04d}.png')
# Generating image for seed 1 (1/500) ...
# Generating image for seed 2 (2/500) ...
# Generating image for seed 3 (3/500) ...
# Generating image for seed 4 (4/500) ...
# Generating image for seed 5 (5/500) ...
# Generating image for seed 6 (6/500) ...
# Generating image for seed 7 (7/500) ...
# Generating image for seed 8 (8/500) ...
# Generating image for seed 9 (9/500) ...
# Generating image for seed 10 (10/500) ...
# ...

# %%
# ============================================
# 🖼️ IMAGE GENERATION + AUTO ZIP
# ============================================

# ✅ Step 1: Generate images using trained model
# !python3.9 /content/stylegan3/gen_images.py \
  --outdir=/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/LB2Generated \
  --seeds=500-4999 \
  --trunc=0.7 \
  --network=/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/00001-stylegan3-r-LateBlight-gpus1-batch8-gamma8.2/network-snapshot-000160.pkl

# ✅ Step 2: Create ZIP of generated images
# !zip -r \
/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/LB2Generated.zip \
/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/LB2Generated > /dev/null

# ✅ Step 3: Display confirmation
import os

gen_path = "/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/LB2Generated"

print("✅ Image generation complete!")
print(f"🖼️ Total generated images: {len(os.listdir(gen_path))}")
print("📁 ZIP saved at:")
print("/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/LB2Generated.zip")
# Out:
# Loading networks from "/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/00001-stylegan3-r-LateBlight-gpus1-batch8-gamma8.2/network-snapshot-000160.pkl"...
# Generating image for seed 500 (0/4500) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
# /content/stylegan3/gen_images.py:137: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(img[0].cpu().numpy(), 'RGB').save(f'{outdir}/seed{seed:04d}.png')
# Generating image for seed 501 (1/4500) ...
# Generating image for seed 502 (2/4500) ...
# Generating image for seed 503 (3/4500) ...
# Generating image for seed 504 (4/4500) ...
# Generating image for seed 505 (5/4500) ...
# Generating image for seed 506 (6/4500) ...
# Generating image for seed 507 (7/4500) ...
# Generating image for seed 508 (8/4500) ...
# Generating image for seed 509 (9/4500) ...
# ...

# %%
import os

# Base path
base_path = "/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r"

# New folder path
new_folder = os.path.join(base_path, "HealthyGenerated")

# Create folder
os.makedirs(new_folder, exist_ok=True)

print(f"✅ Folder created at: {new_folder}")
# Out:
# ✅ Folder created at: /content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/HealthyGenerated

# %%
# ============================================
# 🖼️ IMAGE GENERATION + AUTO ZIP
# ============================================

# ✅ Step 1: Generate images using trained model
# !python3.9 /content/stylegan3/gen_images.py \
  --outdir=/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/EBGenerated \
  --seeds=0-4999 \
  --trunc=0.8 \
  --network=/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/EB/00000-stylegan3-r-EarlyBlight-gpus1-batch8-gamma8.2/network-snapshot-000240.pkl

# ✅ Step 2: Create ZIP of generated images
# !zip -r \
/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/EBGenerated.zip \
/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/EBGenerated > /dev/null

# ✅ Step 3: Display confirmation
import os

gen_path = "/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/EBGenerated"

print("✅ Image generation complete!")
print(f"🖼️ Total generated images: {len(os.listdir(gen_path))}")
print("📁 ZIP saved at:")
print("/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/EBGenerated.zip")
# Out:
# Streaming output truncated to the last 5000 lines.
# Generating image for seed 4 (4/5000) ...
# Generating image for seed 5 (5/5000) ...
# Generating image for seed 6 (6/5000) ...
# Generating image for seed 7 (7/5000) ...
# Generating image for seed 8 (8/5000) ...
# Generating image for seed 9 (9/5000) ...
# Generating image for seed 10 (10/5000) ...
# Generating image for seed 11 (11/5000) ...
# Generating image for seed 12 (12/5000) ...
# Generating image for seed 13 (13/5000) ...
# Generating image for seed 14 (14/5000) ...
# Generating image for seed 15 (15/5000) ...
# Generating image for seed 16 (16/5000) ...
# Generating image for seed 17 (17/5000) ...
# Generating image for seed 18 (18/5000) ...
# Generating image for seed 19 (19/5000) ...
# Generating image for seed 20 (20/5000) ...
# Generating image for seed 21 (21/5000) ...
# Generating image for seed 22 (22/5000) ...
# Generating image for seed 23 (23/5000) ...
# Generating image for seed 24 (24/5000) ...
# ...

# %%
# ============================================
# 🖼️ IMAGE GENERATION + AUTO ZIP
# ============================================

# ✅ Step 1: Generate images using trained model
# !python3.9 /content/stylegan3/gen_images.py \
  --outdir=/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/Healthy/HGenerated \
  --seeds=0-4999 \
  --trunc=0.8 \
  --network=/content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Healthy/00000-stylegan3-r-Healthy-gpus1-batch16-gamma8.2/network-snapshot-000320.pkl

# ✅ Step 2: Create ZIP of generated images
# !zip -r \
/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/Healthy/HGenerated .zip \
/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/Healthy/HGenerated  > /dev/null

# ✅ Step 3: Display confirmation
import os

gen_path = "/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/Healthy/HGenerated"

print("✅ Image generation complete!")
print(f"🖼️ Total generated images: {len(os.listdir(gen_path))}")
print("📁 ZIP saved at:")
print("/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/Healthy/HGenerated.zip")
# Out:
# Streaming output truncated to the last 5000 lines.
# Generating image for seed 4 (4/5000) ...
# Generating image for seed 5 (5/5000) ...
# Generating image for seed 6 (6/5000) ...
# Generating image for seed 7 (7/5000) ...
# Generating image for seed 8 (8/5000) ...
# Generating image for seed 9 (9/5000) ...
# Generating image for seed 10 (10/5000) ...
# Generating image for seed 11 (11/5000) ...
# Generating image for seed 12 (12/5000) ...
# Generating image for seed 13 (13/5000) ...
# Generating image for seed 14 (14/5000) ...
# Generating image for seed 15 (15/5000) ...
# Generating image for seed 16 (16/5000) ...
# Generating image for seed 17 (17/5000) ...
# Generating image for seed 18 (18/5000) ...
# Generating image for seed 19 (19/5000) ...
# Generating image for seed 20 (20/5000) ...
# Generating image for seed 21 (21/5000) ...
# Generating image for seed 22 (22/5000) ...
# Generating image for seed 23 (23/5000) ...
# Generating image for seed 24 (24/5000) ...
# ...

# %%
import shutil

# Folder path
folder_path = "/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/LBGenerated"

# Output zip file path (without .zip)
zip_path = "/content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/LB1Generated"

# Create ZIP
shutil.make_archive(zip_path, 'zip', folder_path)

print("✅ ZIP created successfully:")
print(zip_path + ".zip")
# Out:
# ✅ ZIP created successfully:
# /content/drive/MyDrive/POTATODATASET/PLDDATASET/StyleGAN3-r/LB/LB1Generated.zip

# %%
from pathlib import Path

path = Path("/content/stylegan3/training/training_loop.py")
text = path.read_text()

# Look for the optimizer loop in the fresh file:
snippet_start = text.find("for name, module, opt_kwargs in [")
print(text[snippet_start:snippet_start+400])

# %%
# !zip -r /content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Late_Blight/LBGenerated.zip /content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Late_Blight/LBGenerated
# Out:
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Late_Blight/LBGenerated/ (stored 0%)
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Late_Blight/LBGenerated/seed0000.png (deflated 0%)
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Late_Blight/LBGenerated/seed0001.png (deflated 0%)
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Late_Blight/LBGenerated/seed0002.png (deflated 0%)
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Late_Blight/LBGenerated/seed0003.png (deflated 0%)
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Late_Blight/LBGenerated/seed0004.png (deflated 0%)
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Late_Blight/LBGenerated/seed0005.png (deflated 0%)
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Late_Blight/LBGenerated/seed0006.png (deflated 0%)
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Late_Blight/LBGenerated/seed0007.png (deflated 0%)
# ...

# %%
# !python3.9 -m pip install torch==1.13.1 torchvision==0.14.1
# !python3.9 -m pip install pillow scipy tqdm ninja psutil requests imageio imageio-ffmpeg click pyspng

# %%
# !apt-get install python3.9 python3.9-distutils -y
# !update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.9 1
# !python3 --version
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.9 is already the newest version (3.9.25-1+jammy1).
# python3.9-distutils is already the newest version (3.9.25-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 110 not upgraded.
# Python 3.12.12

# %%
# !pip install ninja
# !python setup.py build_ext --inplace
# Out:
# ...
# python3: can't open file '/content/stylegan3/setup.py': [Errno 2] No such file or directory

# %%
# !ls torch_utils/ops | grep plugin

# %%
# !curl -sS https://bootstrap.pypa.io/get-pip.py | python3.9
# Out:
# ...
#   Using cached pip-26.0-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-26.0-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 26.0
#     Uninstalling pip-26.0:
#       Successfully uninstalled pip-26.0
# ...

# %%
# ============================================
# 🖼️ IMAGE GENERATION + AUTO ZIP
# ============================================

# ✅ Step 1: Generate images using trained model
# !python /content/stylegan3/gen_images.py \
  --outdir=/content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Healthy/HGenerated \
  --seeds=0-1999 \
  --trunc=0.7 \
  --network=/content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Healthy/00000-stylegan3-r-Healthy-gpus1-batch16-gamma8.2/network-snapshot-000280.pkl

# ✅ Step 2: Create ZIP of generated images for download
# !zip -r /content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Early_blight/EBGenerated  > /dev/null

# ✅ Step 4: Display confirmation
import os
print("✅ Image generation complete!")
print(f"Total files: {len(os.listdir('/content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Early_blight'))}")
print("📁 ZIP saved at: /content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Early_blight/EBGenerated.zip")
# Out:
# Loading networks from "/content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Healthy/00000-stylegan3-r-Healthy-gpus1-batch16-gamma8.2/network-snapshot-000280.pkl"...
# Generating image for seed 0 (0/2000) ...
# /content/stylegan3/gen_images.py:137: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   PIL.Image.fromarray(img[0].cpu().numpy(), 'RGB').save(f'{outdir}/seed{seed:04d}.png')
# Generating image for seed 1 (1/2000) ...
# Generating image for seed 2 (2/2000) ...
# Generating image for seed 3 (3/2000) ...
# Generating image for seed 4 (4/2000) ...
# Generating image for seed 5 (5/2000) ...
# Generating image for seed 6 (6/2000) ...
# Generating image for seed 7 (7/2000) ...
# Generating image for seed 8 (8/2000) ...
# Generating image for seed 9 (9/2000) ...
# Generating image for seed 10 (10/2000) ...
# Generating image for seed 11 (11/2000) ...
# Generating image for seed 12 (12/2000) ...
# Generating image for seed 13 (13/2000) ...
# ...

# %%
# !zip -r /content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Healthy/HGenerated.zip  /content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Healthy/HGenerated
# Out:
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Healthy/HGenerated/ (stored 0%)
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Healthy/HGenerated/seed0000.png (deflated 0%)
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Healthy/HGenerated/seed0001.png (deflated 0%)
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Healthy/HGenerated/seed0002.png (deflated 0%)
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Healthy/HGenerated/seed0003.png (deflated 0%)
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Healthy/HGenerated/seed0004.png (deflated 0%)
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Healthy/HGenerated/seed0005.png (deflated 0%)
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Healthy/HGenerated/seed0006.png (deflated 0%)
#   adding: content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Healthy/HGenerated/seed0007.png (deflated 0%)
# ...

# %%
sed -n '1,200p' /content/stylegan3/gen_images.py
# Out:
#   File "/tmp/ipython-input-2201439786.py", line 1
#     sed -n '1,200p' /content/stylegan3/gen_images.py
#            ^
# SyntaxError: invalid syntax

# %%
# %%bash
# sed -i "s/device = torch.device('cuda')/device = torch.device('cpu')/g" /content/stylegan3/gen_images.py

# %%
# !grep "device = torch.device" /content/stylegan3/gen_images.py
# Out:
#     device = torch.device('cpu')

# %%
# %%bash
# export CUDA_VISIBLE_DEVICES=""
#
# python3 /content/stylegan3/gen_images.py \
#   --network=/content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Late_Blight/00000-stylegan3-r-Late_blight-gpus1-batch8-gamma8.2/network-snapshot-000160.pkl \
#   --outdir=/content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Late_Blight/LBGenerated \
#   --seeds=0-1999 \
#   --trunc=0.7
# Out:
# Process is terminated.

# %%
# !zip -r /content/drive/MyDrive/POTATODATASET/Healthy.zip /content/drive/MyDrive/POTATODATASET/Healthy
# Out:
#   adding: content/drive/MyDrive/POTATODATASET/Healthy/ (stored 0%)
#   adding: content/drive/MyDrive/POTATODATASET/Healthy/00fc2ee5-729f-4757-8aeb-65c3355874f2___RS_HL 1864.JPG (deflated 1%)
#   adding: content/drive/MyDrive/POTATODATASET/Healthy/111cd9d8-4d27-4225-be9e-d29b21cf56b9___RS_HL 5419.JPG (deflated 1%)
#   adding: content/drive/MyDrive/POTATODATASET/Healthy/170f1f57-0fd4-421f-9c82-3b1804be63ad___RS_HL 1771.JPG (deflated 1%)
#   adding: content/drive/MyDrive/POTATODATASET/Healthy/163ada72-4288-4f85-a3c1-feed23c8d1de___RS_HL 1940.JPG (deflated 1%)
#   adding: content/drive/MyDrive/POTATODATASET/Healthy/1b434c52-7be4-40c4-90d5-13220f1a3eba___RS_HL 5418.JPG (deflated 1%)
#   adding: content/drive/MyDrive/POTATODATASET/Healthy/22322780-95b4-4b45-b626-26b22965d55e___RS_HL 1880.JPG (deflated 1%)
#   adding: content/drive/MyDrive/POTATODATASET/Healthy/1ae826e2-5148-47bd-a44c-711ec9cc9c75___RS_HL 1954.JPG (deflated 1%)
# ...

# %%
# Early_Blight StyleGAN3-r
# !python3.9 /content/stylegan3/train.py \
  --outdir=/content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Early_blight \
  --data=/content/drive/MyDrive/POTATODATASET/Early_blight.zip \
  --gpus=1 \
  --batch=8 \
  --cfg=stylegan3-r \
  --gamma=8.2 \
  --snap=10 \
  --kimg=500 \
  --mirror=1\
  --metrics=none
# Out:
# /content/stylegan3/torch_utils/ops/conv2d_gradfix.py:14: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
#
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 65536,
#     "channel_max": 1024,
#     "magnitude_ema_beta": 0.9997227795604651,
#     "conv_kernel": 1,
#     "use_radial_filters": true
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
# ...

# %%
# Early_Blight StyleGAN3-r
# !python3.9 /content/stylegan3/train.py \
  --outdir=/content/drive/MyDrive/POTATODATASET/StyleGAN3-r/Healthy \
  --data=/content/drive/MyDrive/POTATODATASET/Healthy.zip \
  --gpus=1 \
  --batch=16 \
  --cfg=stylegan3-r \
  --gamma=8.2 \
  --snap=10 \
  --kimg=500 \
  --mirror=1\
  --metrics=none
# Out:
# /content/stylegan3/torch_utils/ops/conv2d_gradfix.py:14: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
#
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 65536,
#     "channel_max": 1024,
#     "magnitude_ema_beta": 0.9994456359721023,
#     "conv_kernel": 1,
#     "use_radial_filters": true
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
# ...
